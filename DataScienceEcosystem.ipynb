# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Hands-on Lab: Create your Jupyter Notebook

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# ![ejercicio1.png](attachment:38737d1c-5733-4328-b667-2ab09066a272.png)

# %%
# Herramientas y ecosistema de ciencia de datos

# %% [markdown]
# Copyright ©2024 IBM Corporation. All rights reserved.

# %% [markdown]
# ![Captura de pantalla 2024-10-31 045729.png](attachment:25998337-8d6e-4a88-a202-57af6474f750.png)

# %%
En este cuaderno, se resumen las herramientas y el ecosistema de ciencia de datos.

# %%
Algunos de los lenguajes populares que usan los científicos de datos son:
1. Python
2. R
3. SQL

# %% [markdown]
# ![Captura de pantalla 2024-10-31 045821.png](attachment:439a8f68-c9dc-44de-804e-a877d2273f24.png)

# %%
Algunas de las bibliotecas comúnmente usadas por los científicos de datos incluyen:
1. Pandas
2. NumPy
3. Scikit-learn

# %%
| Herramientas de ciencia de datos |
|----------------------------------|
| Jupyter Notebook                  |
| RStudio                           |
| Apache Spark                      |

# %%
### A continuación, se muestran algunos ejemplos de evaluación de expresiones aritméticas en Python.

# %% [markdown]
# ![Captura de pantalla 2024-10-31 045911.png](attachment:7bf05d50-0bd5-41a9-bb9a-e08f1919ce8e.png)

# %%
# Esta es una expresión aritmética simple para multiplicar y luego sumar números enteros.
resultado = (3 * 4) + 5
resultado
# Out:
# 17

# %%
# Esto convertirá 200 minutos en horas al dividirlos en 60.
horas = 200 / 60
horas

# %%
**Objetivos:**
- Enumerar los lenguajes populares para la ciencia de datos.
- Listar bibliotecas utilizadas en ciencia de datos.
- Presentar herramientas de desarrollo.

# %%
## Autor
Tu Nombre Aquí francisco alvial

# %% [markdown]
# ![Captura de pantalla 2024-10-31 045955.png](attachment:974e94e6-a60c-490d-98b6-d36afe468e3a.png)
